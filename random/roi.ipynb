# %%
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = r"C:\Users\shash\OneDrive\Documents\AI_Data\1.5 mM h2o2\122.9325.jpg"

# %%
rois = [
    (2403,1317, 2553,1467)
]

# %%
image = Image.open(image_path)
image.size
# Out:
# (4032, 3024)

# %%
roi_image = image.crop(rois[0])
rgb_values = roi_image.getdata()

# %%
roi_image
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
img = cv2.imread(image_path)
lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
lab
# Out:
# array([[[  1, 128, 128],
#         [  1, 128, 128],
#         [  0, 128, 128],
#         ...,
#         [  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128]],
#
#        [[  1, 128, 128],
#         [  1, 128, 128],
#         [  1, 128, 128],
#         ...,
#         [  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128]],
#
#        [[  1, 128, 128],
#         [  1, 128, 128],
#         [  1, 128, 128],
#         ...,
#         [  0, 128, 128],
#         [  0, 128, 128],
#         [  0, 128, 128]],
#
#        ...,
#
#        [[  0, 128, 128],
#         [  0, 128, 128],
#         [  1, 128, 128],
#         ...,
#         [  1, 128, 128],
#         [  1, 126, 129],
#         [  1, 126, 129]],
#
#        [[  0, 128, 128],
#         [  1, 128, 128],
#         [  1, 128, 128],
#         ...,
#         [  1, 128, 128],
#         [  1, 126, 129],
#         [  1, 126, 129]],
#
#        [[  1, 128, 128],
#         [  1, 128, 128],
#         [  1, 128, 128],
# ...

# %%
mask = cv2.inRange(lab, np.array([1,120,0]), np.array([1,140,140]))
plt.imshow(mask)
